# %%
import os,sys
import json
import torch

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
# 构建数据集
from torch.utils.data import DataLoader,Subset
from src.dataset import build_global_vocab_and_maxcount, CLEVRMultiLabelByImage

clevr_root = "../CLEVR_v1.0"

# 全局统计：colors/shapes/max_objects（train+val+test）
colors, shapes, max_objects, _ = build_global_vocab_and_maxcount(clevr_root, splits=("train","val"))

print("num_colors:", len(colors), colors)
print("num_shapes:", len(shapes), shapes)
print("max_objects:", max_objects)

tfm64 = T.Compose([
    T.Resize((64, 64)),
    T.ToTensor(),
])

tfm128 = T.Compose([
    T.Resize((128, 128)),
    T.ToTensor(),
])

train_ds_64 = CLEVRMultiLabelByImage(
    clevr_root=clevr_root,
    split="train",
    colors=colors,
    shapes=shapes,
    max_objects=max_objects,
    transform=tfm64
)

train_ds_128 = CLEVRMultiLabelByImage(
    clevr_root=clevr_root,
    split="train",
    colors=colors,
    shapes=shapes,
    max_objects=max_objects,
    transform=tfm128
)

train_dl_64 = DataLoader(train_ds_64, batch_size=100, shuffle=True, num_workers=0)
train_dl_128 = DataLoader(train_ds_128, batch_size=100, shuffle=True, num_workers=0)
# Out:
# num_colors: 8 ['blue', 'brown', 'cyan', 'gray', 'green', 'purple', 'red', 'yellow']
# num_shapes: 3 ['cube', 'cylinder', 'sphere']
# max_objects: 10
# images: torch.Size([100, 3, 224, 224])
# color_mh: torch.Size([100, 8])
# shape_mh: torch.Size([100, 3])
# count_oh: torch.Size([100, 11])
# example fn: CLEVR_train_028897.png
# example count one-hot argmax: 9

# %%
# 构建模型
from src.model import REVAE_V1

revae_64 = REVAE_V1()
revae_128 = REVAE_V1()

# %%
from src.train import TrainConfig, fit, evaluate
import torch.optim as optim

cfg64 = TrainConfig(
    epochs=100,
    lr=1e-3,
    beta_kl=1,
    lam_color=0,
    lam_shape=0,
    lam_count=0,
    recon_loss="bce_logits",   # 你已确认 images 在 [0,1] bce_logits\mse\l1
    use_amp=False,
    log_every=100,
    save_best=False,
    ckpt_dir="../checkpoints",
    ckpt_name="revae_v64.pt",
    device="cuda" if torch.cuda.is_available() else "cpu",
)

cfg128 = TrainConfig(
    epochs=100,
    lr=1e-3,
    beta_kl=1,
    lam_color=0,
    lam_shape=0,
    lam_count=0,
    recon_loss="bce_logits",   # 你已确认 images 在 [0,1] bce_logits\mse\l1
    use_amp=False,
    log_every=100,
    save_best=False,
    ckpt_dir="../checkpoints",
    ckpt_name="revae_v128.pt",
    device="cuda" if torch.cuda.is_available() else "cpu",
)

optimizer64 = optim.Adam(revae_64.parameters(), lr=cfg64.lr)
optimizer128 = optim.Adam(revae_128.parameters(), lr=cfg128.lr)

# 若你还没做 val_dl，可以先 val_loader=None
result = fit(revae_64, train_dl_64, optimizer64, cfg64, val_loader=None)
# Out:
# epoch1
# d:\github file\REVAE\src\train.py:137: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(cfg.use_amp and device.type == "cuda"))
# d:\github file\REVAE\src\train.py:152: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(cfg.use_amp and device.type == "cuda")):
# [train] epoch 1 step 0/700 total=113803.2266 recon=113802.9609 kl=0.2647 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 1 step 100/700 total=103110.3906 recon=102987.4375 kl=122.9548 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 1 step 200/700 total=102936.2422 recon=102870.5156 kl=65.7277 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 1 step 300/700 total=102820.4062 recon=102768.8594 kl=51.5507 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 1 step 400/700 total=102676.5078 recon=102554.8203 kl=121.6905 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 1 step 500/700 total=102646.7031 recon=102590.1406 kl=56.5633 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 1 step 600/700 total=102552.2734 recon=102503.6172 kl=48.6561 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# epoch2
# [train] epoch 2 step 0/700 total=102369.8359 recon=102320.3750 kl=49.4619 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 2 step 100/700 total=102355.4688 recon=102303.7812 kl=51.6900 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 2 step 200/700 total=102227.6562 recon=102180.2812 kl=47.3721 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 2 step 300/700 total=102334.0469 recon=102294.8594 kl=39.1870 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 2 step 400/700 total=102397.1562 recon=102349.3359 kl=47.8173 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 2 step 500/700 total=102248.4688 recon=102200.9609 kl=47.5063 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 2 step 600/700 total=102315.2578 recon=102272.4766 kl=42.7798 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# epoch3
# [train] epoch 3 step 0/700 total=102261.2891 recon=102218.5547 kl=42.7373 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 3 step 100/700 total=102253.3359 recon=102208.5000 kl=44.8347 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 3 step 200/700 total=102210.7969 recon=102170.6562 kl=40.1403 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 3 step 300/700 total=102222.3594 recon=102181.1406 kl=41.2205 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 3 step 400/700 total=102140.8750 recon=102103.5156 kl=37.3605 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 3 step 500/700 total=102202.0078 recon=102161.0703 kl=40.9339 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 3 step 600/700 total=102126.5547 recon=102088.4609 kl=38.0961 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# epoch4
# [train] epoch 4 step 0/700 total=102049.4141 recon=102008.8281 kl=40.5831 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 4 step 100/700 total=102072.7422 recon=102033.1484 kl=39.5972 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 4 step 200/700 total=102329.5078 recon=102294.2969 kl=35.2075 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 4 step 300/700 total=102160.7422 recon=102123.2109 kl=37.5320 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 4 step 400/700 total=102021.9141 recon=101982.4609 kl=39.4546 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 4 step 500/700 total=102003.2656 recon=101964.3984 kl=38.8691 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 4 step 600/700 total=101929.6719 recon=101889.9453 kl=39.7282 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# epoch5
# [train] epoch 5 step 0/700 total=102124.9922 recon=102082.3750 kl=42.6158 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 5 step 100/700 total=102047.1172 recon=101998.8984 kl=48.2159 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 5 step 200/700 total=102169.4062 recon=102127.9844 kl=41.4186 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 5 step 300/700 total=101947.3281 recon=101902.7812 kl=44.5498 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 5 step 400/700 total=102063.3516 recon=102019.9297 kl=43.4198 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 5 step 500/700 total=102194.8984 recon=102151.6016 kl=43.2971 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 5 step 600/700 total=102227.9531 recon=102185.6641 kl=42.2915 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# epoch6
# [train] epoch 6 step 0/700 total=101945.0078 recon=101901.9766 kl=43.0311 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 6 step 100/700 total=101981.4062 recon=101919.1953 kl=62.2142 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 6 step 200/700 total=102100.4688 recon=102052.7266 kl=47.7437 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 6 step 300/700 total=102149.5156 recon=102098.1797 kl=51.3363 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 6 step 400/700 total=101911.1719 recon=101861.6562 kl=49.5143 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 6 step 500/700 total=101976.6406 recon=101933.7266 kl=42.9115 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 6 step 600/700 total=102045.5078 recon=101999.5391 kl=45.9688 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# epoch7
# [train] epoch 7 step 0/700 total=101846.6250 recon=101801.4844 kl=45.1394 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 7 step 100/700 total=101960.5781 recon=101918.5781 kl=42.0031 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 7 step 200/700 total=102225.7266 recon=102182.3281 kl=43.3965 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 7 step 300/700 total=102130.9062 recon=102092.2188 kl=38.6882 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 7 step 400/700 total=102166.5312 recon=102125.2266 kl=41.3044 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 7 step 500/700 total=102053.3750 recon=102009.8984 kl=43.4752 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 7 step 600/700 total=102087.5000 recon=102047.0781 kl=40.4248 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# epoch8
# [train] epoch 8 step 0/700 total=102084.1094 recon=102042.0078 kl=42.1015 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 8 step 100/700 total=101884.2266 recon=101841.5859 kl=42.6398 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 8 step 200/700 total=102051.2969 recon=102009.7109 kl=41.5838 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 8 step 300/700 total=102154.0312 recon=102114.1562 kl=39.8723 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 8 step 400/700 total=102003.7422 recon=101963.4375 kl=40.3040 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 8 step 500/700 total=102029.0312 recon=101990.7656 kl=38.2682 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 8 step 600/700 total=101991.9453 recon=101950.3750 kl=41.5698 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# epoch9
# [train] epoch 9 step 0/700 total=102101.9609 recon=102057.7656 kl=44.1943 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 9 step 100/700 total=101956.2891 recon=101912.7578 kl=43.5287 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 9 step 200/700 total=102020.2344 recon=101980.8594 kl=39.3781 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 9 step 300/700 total=101839.4297 recon=101798.6406 kl=40.7886 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 9 step 400/700 total=102027.6016 recon=101984.2891 kl=43.3107 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 9 step 500/700 total=101843.5938 recon=101802.2656 kl=41.3309 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 9 step 600/700 total=102073.9062 recon=102027.6406 kl=46.2680 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# epoch10
# [train] epoch 10 step 0/700 total=101918.7344 recon=101875.8984 kl=42.8327 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 10 step 100/700 total=101812.2656 recon=101767.4609 kl=44.8034 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 10 step 200/700 total=101933.4375 recon=101888.2344 kl=45.2033 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 10 step 300/700 total=101974.2344 recon=101932.7500 kl=41.4850 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 10 step 400/700 total=102036.2344 recon=101996.5156 kl=39.7158 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 10 step 500/700 total=101994.0469 recon=101951.8359 kl=42.2084 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 10 step 600/700 total=101953.8438 recon=101915.0703 kl=38.7758 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# ../checkpoints\revae_v2.pt

# %%
result = fit(revae_128, train_dl_128, optimizer128, cfg128, val_loader=None)
