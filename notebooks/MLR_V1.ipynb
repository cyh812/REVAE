# %%
import os,sys
import json
import torch

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
# 构建数据集
from torch.utils.data import DataLoader,Subset
from src.dataset import build_global_vocab_and_maxcount, CLEVRMultiLabelByImage

clevr_root = "../CLEVR_v1.0"

# 全局统计：colors/shapes/max_objects（train+val+test）
colors, shapes, max_objects, _ = build_global_vocab_and_maxcount(clevr_root, splits=("train","val"))

print("num_colors:", len(colors), colors)
print("num_shapes:", len(shapes), shapes)
print("max_objects:", max_objects)

train_ds = CLEVRMultiLabelByImage(
    clevr_root=clevr_root,
    split="train",
    colors=colors,
    shapes=shapes,
    max_objects=max_objects,
)

train_dl = DataLoader(train_ds, batch_size=100, shuffle=True, num_workers=0)
# Out:
# num_colors: 8 ['blue', 'brown', 'cyan', 'gray', 'green', 'purple', 'red', 'yellow']
# num_shapes: 3 ['cube', 'cylinder', 'sphere']
# max_objects: 10

# %%
# 构建模型
from src.model import REVAE_V1

revae = REVAE_V1()

# %%
from src.train import TrainConfig, fit, evaluate
import torch.optim as optim

cfg = TrainConfig(
    epochs=50,
    lr=1e-3,
    beta_kl=1,
    lam_color=0,
    lam_shape=0,
    lam_count=0,
    recon_loss="bce_logits",   # 你已确认 images 在 [0,1] bce_logits\mse\l1
    use_amp=False,
    log_every=700,
    save_best=False,
    ckpt_dir="../checkpoints",
    ckpt_name="revae_v224.pt",
    device="cuda" if torch.cuda.is_available() else "cpu",
)

optimizer = optim.Adam(revae.parameters(), lr=cfg.lr)

# 若你还没做 val_dl，可以先 val_loader=None
result = fit(revae, train_dl, optimizer, cfg, val_loader=None)
print(result["ckpt_path"])
# Out:
# d:\github file\REVAE\src\train.py:137: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(cfg.use_amp and device.type == "cuda"))
# d:\github file\REVAE\src\train.py:152: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(cfg.use_amp and device.type == "cuda")):
# [train] epoch 1total=103852.4108 recon=103851.1620 kl=1.2488 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 2total=103742.0716 recon=103742.0716 kl=0.0000 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 3total=103740.3450 recon=103740.3450 kl=0.0000 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 4total=103132.3272 recon=103121.4926 kl=10.8347 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 5total=102060.1611 recon=102014.6744 kl=45.4868 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 6total=101840.6340 recon=101785.7934 kl=54.8406 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 7total=101738.5801 recon=101679.6624 kl=58.9177 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 8total=101672.7852 recon=101611.8106 kl=60.9746 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 9total=101634.2065 recon=101572.2940 kl=61.9125 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 10total=101609.2847 recon=101546.6016 kl=62.6833 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 11total=101591.6758 recon=101528.3896 kl=63.2863 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 12total=101576.2996 recon=101512.3425 kl=63.9572 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 13total=101564.8550 recon=101500.3669 kl=64.4881 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 14total=101552.8879 recon=101487.8362 kl=65.0515 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 15total=101541.7345 recon=101476.0801 kl=65.6545 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 16total=101535.1638 recon=101469.1396 kl=66.0242 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 17total=101525.7951 recon=101459.3243 kl=66.4708 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 18total=101518.9894 recon=101452.1351 kl=66.8543 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 19total=101512.9719 recon=101445.8265 kl=67.1456 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 20total=101506.7361 recon=101439.2590 kl=67.4771 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 21total=101502.1675 recon=101434.4591 kl=67.7084 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 22total=101497.2548 recon=101429.3040 kl=67.9509 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 23total=101491.8596 recon=101423.6273 kl=68.2324 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 24total=101488.9780 recon=101420.5890 kl=68.3890 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 25total=101484.2593 recon=101415.6236 kl=68.6357 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 26total=101481.6230 recon=101412.8538 kl=68.7691 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 27total=101477.6257 recon=101408.6964 kl=68.9293 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 28total=101474.8203 recon=101405.6794 kl=69.1409 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 29total=101471.4739 recon=101402.1285 kl=69.3454 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 30total=101469.5278 recon=101400.0861 kl=69.4418 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 31total=101465.9538 recon=101396.3521 kl=69.6016 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 32total=101463.8925 recon=101394.1746 kl=69.7180 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 33total=101461.2244 recon=101391.3983 kl=69.8261 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 34total=101459.3215 recon=101389.3805 kl=69.9411 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 35total=101456.8264 recon=101386.7201 kl=70.1064 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 36total=101454.7654 recon=101384.6186 kl=70.1467 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 37total=101452.4943 recon=101382.1697 kl=70.3246 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 38total=101451.0005 recon=101380.6788 kl=70.3218 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 39total=101448.6613 recon=101378.1859 kl=70.4753 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 40total=101448.3858 recon=101377.8184 kl=70.5674 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 41total=101445.6260 recon=101374.9765 kl=70.6495 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 42total=101442.9823 recon=101372.2424 kl=70.7400 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 43total=101441.8526 recon=101371.0170 kl=70.8355 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 44total=101440.1893 recon=101369.2695 kl=70.9199 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 45total=101439.2579 recon=101368.2594 kl=70.9986 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 46total=101437.4492 recon=101366.3051 kl=71.1443 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 47total=101435.6913 recon=101364.5570 kl=71.1343 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 48total=101434.7892 recon=101363.5233 kl=71.2660 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 49total=101433.5906 recon=101362.2891 kl=71.3015 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# [train] epoch 50total=101432.1270 recon=101360.7426 kl=71.3844 loss_color=0.0000 loss_shape=0.0000 loss_count=0.0000
# ../checkpoints\revae_v224.pt

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

ckpt_path = "../checkpoints/revae_v224.pt"  # 你的实际路径
revae = REVAE_V1().to(device)

ckpt = torch.load(ckpt_path, map_location=device)

# 如果你保存的是 {"model": state_dict, ...}
if isinstance(ckpt, dict) and "model" in ckpt:
    revae.load_state_dict(ckpt["model"])
else:
    # 如果你保存的就是纯 state_dict
    revae.load_state_dict(ckpt)

revae.eval()
print("Loaded checkpoint from:", ckpt_path)
# Out:
# Loaded checkpoint from: ../checkpoints/revae_v224.pt
# C:\Users\cyh\AppData\Local\Temp\ipykernel_35928\2972750944.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path, map_location=device)

# %%
# 取第 i 张（你可以换 i）
i = 1100
image, color_mh, shape_mh, count_oh, img_fn = train_ds[i]

print("file:", img_fn)
print("gt count:", int(count_oh.argmax()))
# Out:
# file: CLEVR_train_001100.png
# gt count: 10

# %%
import torch.nn.functional as F

def decode_multihot(mh, names, thr=0.5):
    """mh: (K,) in {0,1} or prob; names: list[str] length K"""
    idx = (mh >= thr).nonzero(as_tuple=True)[0].tolist()
    return [names[j] for j in idx]

with torch.no_grad():
    x = image.unsqueeze(0).to(device)  # (1,3,224,224)

    out = revae(x)
    if isinstance(out, (tuple, list)) and len(out) == 3:
        x_logits, post, heads = out
    else:
        # 如果你 forward 返回 dict
        x_logits, post, heads = out["x_logits"], out["post"], out["heads"]

    p = torch.sigmoid(x_logits)
    print("pred mean:", p.mean().item(), "pred max:", p.max().item(), "pred min:", p.min().item())
    print("gt mean:", image.mean().item(), "gt max:", image.max().item(), "gt min:", image.min().item())
    # --- 预测 ---
    color_prob = torch.sigmoid(heads["color_logits"])[0].detach().cpu()  # (8,)
    shape_prob = torch.sigmoid(heads["shape_logits"])[0].detach().cpu()  # (3,)
    count_pred = heads["count_logits"].argmax(dim=1)[0].item()           # int 0..10

    # --- 重建 ---
    recon = torch.sigmoid(x_logits)[0].detach().cpu()  # (3,224,224) in [0,1]

print("Pred count:", count_pred)
print("Pred colors:", decode_multihot(color_prob, colors, thr=0.5))
print("Pred shapes:", decode_multihot(shape_prob, shapes, thr=0.5))

gt_colors = decode_multihot(color_mh, colors, thr=0.5)
gt_shapes = decode_multihot(shape_mh, shapes, thr=0.5)
gt_count  = int(count_oh.argmax())

print("GT count:", gt_count)
print("GT colors:", gt_colors)
print("GT shapes:", gt_shapes)
# Out:
# pred mean: 0.4483770728111267 pred max: 0.6446741223335266 pred min: 0.13416388630867004
# gt mean: 0.4489869475364685 gt max: 0.9843137264251709 gt min: 0.01568627543747425
# Pred count: 8
# Pred colors: ['green', 'red']
# Pred shapes: []
# GT count: 10
# GT colors: ['blue', 'brown', 'gray', 'green', 'purple', 'red', 'yellow']
# GT shapes: ['cube', 'cylinder', 'sphere']

# %%
import matplotlib.pyplot as plt

def show_img(t):
    # t: (3,H,W) in [0,1]
    t = t.permute(1,2,0).numpy()
    plt.imshow(t)
    plt.axis("off")

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.title("Input")
show_img(image)          # dataset 给的 image 通常已是 [0,1]

plt.subplot(1,2,2)
plt.title("Reconstruction")
show_img(recon)

plt.show()
